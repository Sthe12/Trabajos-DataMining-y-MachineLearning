# %%
# This R environment comes with many helpful analytics packages installed
# It is defined by the kaggle/rstats Docker image: https://github.com/kaggle/docker-rstats
# For example, here's a helpful package to load

library(tidyverse) # metapackage of all tidyverse packages

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

list.files(path = "../input")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# [1] "datataller2"

# %% [markdown]
# # **2 Hands On: Data Quality and Pre-Processing**

# %% [markdown]
# **1. Assessing Data Quality**

# %% [markdown]
# Load the following packages: dplyr, na.tools, tidyimpute (version from github
# decisionpatterns/tidyimpute”)

# %%
library(devtools)
#install_github( "decisionpatterns/tidyimport"
install.packages("tidyimpute")
# Out:
# Loading required package: usethis
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “unable to access index for repository http://cran.rstudio.com/src/contrib:
#   cannot open URL 'http://cran.rstudio.com/src/contrib/PACKAGES'”
# Warning message:
# “package ‘tidyimpute’ is not available for this version of R
#
# A version of this package for your version of R might be available elsewhere,
# see the ideas at
# https://cran.r-project.org/doc/manuals/r-patched/R-admin.html#Installing-packages”

# %% [markdown]
# Load the carInsurance data set about the insurance risk rating of cars based on several characteristics of each car1

# %%
#df <- read.Rdata('/kaggle/input/datataller2/carInsurance.Rdata')
#head(df)
#df

#print(nrow(df))
df <- load("/kaggle/input/datataller2/carInsurance.Rdata")
print(df)
# Out:
# [1] "carIns"

# %% [markdown]
# (a) Check if there are any missing values.

# %%
print(apply(df, 2, anyNA))
print("=======================")
missing_values <- sapply(df, function(x) sum(is.na(x)))
print(missing_values)
# Out:
# Error in apply(df, 2, anyNA): dim(X) must have a positive length
# Traceback:
#
# 1. print(apply(df, 2, anyNA))
# 2. apply(df, 2, anyNA)
# 3. stop("dim(X) must have a positive length")

# %% [markdown]
# (b) Count the number of cases that have, at least, one missing value.

# %%
library(dplyr)
count_na_cases <- df %>%
  filter_any_na() %>%
  count()
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# Error in filter_any_na(.): could not find function "filter_any_na"
# Traceback:
#
# 1. df %>% filter_any_na() %>% count()
# 2. count(.)

# %% [markdown]
# (c) Create a new data set by removing all the cases that have missing values.

# %% [markdown]
# (d) Create a new data set by imputing all the missing values with 0.

# %% [markdown]
# (e) Create a new data set by imputing the mean in all the columns which have double type values.

# %% [markdown]
# (f) Create a new data set by imputing the mode in all the columns which have integer type values

# %% [markdown]
# (g) Create a new data set by imputing the most frequent value to the column ”nDoors”.

# %% [markdown]
# (h) Combine the three last imputations to obtain a final dataset. Are there any duplicated cases?
